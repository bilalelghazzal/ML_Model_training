# %% [markdown]
# <a href="https://colab.research.google.com/github/bilalelghazzal/kaggle_python_training/blob/main/Copie_de_CICDDOS_2017.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Importer le fichier kaggle.json que vous venez de télécharger
from google.colab import files
print("Veuillez sélectionner votre fichier 'kaggle.json' :")
files.upload()
# Out:
# Veuillez sélectionner votre fichier 'kaggle.json' :
#      <input type="file" id="files-2363ca8b-2785-458e-9a9a-8383cbb7fbaf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2363ca8b-2785-458e-9a9a-8383cbb7fbaf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# 2. Configurer le dossier Kaggle en arrière-plan
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# 3. Télécharger le dataset (le nom correspond à la fin de votre URL Kaggle)
# !kaggle datasets download -d ericanacletoribeiro/cicids2017-cleaned-and-preprocessed

# 4. Dézipper le fichier téléchargé
import zipfile
import os

zip_file = "cicids2017-cleaned-and-preprocessed.zip"
if os.path.exists(zip_file):
    with zipfile.ZipFile(zip_file, 'r') as zip_ref:
        zip_ref.extractall("cicids2017_data")
    print("Le dataset a été téléchargé et dézippé avec succès !")
    # Afficher les fichiers extraits pour voir le nom exact du CSV
    print("Fichiers disponibles :", os.listdir("cicids2017_data"))
else:
    print("Erreur lors du téléchargement.")
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/ericanacletoribeiro/cicids2017-cleaned-and-preprocessed
# License(s): CC0-1.0
# ...
# 100% 200M/200M [00:02<00:00, 91.9MB/s]
#
# Le dataset a été téléchargé et dézippé avec succès !
# Fichiers disponibles : ['cicids2017_cleaned.csv']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# 1. Définir le chemin exact du fichier (visible sur votre image)
chemin_csv = "cicids2017_data/cicids2017_cleaned.csv"

print("Chargement du dataset en cours (cela peut prendre quelques secondes)...")

df = pd.read_csv(chemin_csv)

print("Dataset chargé avec succès ! ")

# 3. Afficher les dimensions du dataset (Lignes, Colonnes)
print(f"Dimensions : {df.shape[0]} lignes et {df.shape[1]} colonnes.\n")
df.head()
# Out:
# Chargement du dataset en cours (cela peut prendre quelques secondes)...
# Dataset chargé avec succès !
# Dimensions : 2520751 lignes et 53 colonnes.
#    Destination Port  Flow Duration  Total Fwd Packets  \
# 0                22        1266342                 41
# 1                22        1319353                 41
# 2                22            160                  1
# 3                22        1303488                 41
# 4             35396             77                  1
#
#    Total Length of Fwd Packets  Fwd Packet Length Max  Fwd Packet Length Min  \
# 0                         2664                    456                      0
# 1                         2664                    456                      0
# 2                            0                      0                      0
# 3                         2728                    456                      0
# 4                            0                      0                      0
#
# ...

# %%
df.drop_duplicates(inplace=True)
print(f"Nouvelles dimensions après suppression des doublons : {df.shape[0]} lignes et {df.shape[1]} colonnes.")
# Out:
# Nouvelles dimensions après suppression des doublons : 2520590 lignes et 53 colonnes.

# %%
X=df.drop('Attack Type',axis=1)
y=df['Attack Type']
print(y)
# Out:
# 0          Normal Traffic
# 1          Normal Traffic
# 2          Normal Traffic
# 3          Normal Traffic
# 4          Normal Traffic
#                 ...
# 2520746    Normal Traffic
# 2520747    Normal Traffic
# 2520748    Normal Traffic
# 2520749    Normal Traffic
# 2520750    Normal Traffic
# Name: Attack Type, Length: 2520590, dtype: object

# %% [markdown]
# ## How to Push This Notebook to GitHub
#
# 1.  **Create a GitHub Repository (if you don't have one already):**
#     *   Go to [GitHub](https://github.com/new).
#     *   Click on the green 'New' button to create a new repository.
#     *   Give it a name (e.g., `my_colab_notebooks`), an optional description, choose public or private, and click 'Create repository'.
#
# 2.  **Save a Copy of Your Notebook to GitHub from Colab:**
#     *   In your Colab notebook, go to the top menu.
#     *   Click on **File**.
#     *   Select **'Save a copy to GitHub'**.
#
# 3.  **Authenticate and Choose Repository:**
#     *   If prompted, you may need to authenticate your GitHub account with Colab.
#     *   A dialog will appear where you can select your GitHub organization/user and the repository you created (e.g., `my_colab_notebooks`).
#     *   You can also specify a file path within the repository if you want to organize your notebooks in subfolders.
#     *   Click **'OK'** or **'Save'**.
#
# This will push the current state of your notebook directly to your chosen GitHub repository.
